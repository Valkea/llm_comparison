# %%
# !pip install -q -U bitsandbytes
# !pip install -q -U accelerate
# !pip install -q -U transformers
# !pip install -q -U torch
# !pip install -q -U einops
# !pip install -q -U xformers
# !pip install -q -U evaluate
# !pip install -q -U pandas
# !pip install -q -U python-dotenv

# %%
# !nvidia-smi
# Out:
# Wed Jul 19 20:49:27 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    25W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Connect to Google Drive in order to store the HF models for the next time

# %%
import os
from google.colab import drive

drive.mount('/content/drive')

os.environ['TRANSFORMERS_CACHE'] = '/content/drive/MyDrive/Colab Notebooks/NLP/HuggingfaceCash'
os.environ['HF_DATASETS_CACHE'] = '/content/drive/MyDrive/Colab Notebooks/NLP/HuggingfaceCash/Datasets'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import re
import time
import pathlib

import pandas as pd

from transformers import AutoTokenizer, AutoModelForCausalLM #, AutoModelForMaskedLM
import transformers
import torch

# %% [markdown]
# ### Load the model and tokenizer

# %%
from dotenv import load_dotenv, find_dotenv

_ = load_dotenv(find_dotenv())  # read local .env file

access_token = os.environ["LLAMA2_HF_API_KEY"]

# %%
model_name = 'meta-llama/Llama-2-7b-chat-hf'

model = AutoModelForCausalLM.from_pretrained(model_name, load_in_4bit=True, device_map="auto", use_auth_token=access_token)
tokenizer = AutoTokenizer.from_pretrained(model_name, use_auth_token=access_token)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/770 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1714: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)in/added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %% [markdown]
# ### Prepare the pipeline

# %%
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    # torch_dtype=torch.bfloat16,
    # trust_remote_code=True,
    # device_map="auto",
)

# %% [markdown]
# ### Add stop words to control the output

# %%
from transformers import StoppingCriteriaList, StoppingCriteria
class StoppingCriteriaSub(StoppingCriteria):

    def __init__(self, stops = [], encounters=1):
        super().__init__()
        self.stops = [stop.to("cuda") for stop in stops]

    def __call__(self, input_ids: torch.LongTensor, scores: torch.FloatTensor):
        for stop in self.stops:
            if torch.all((stop == input_ids[0][-len(stop):])).item():
                return True

        return False


stop_words = ["\n","agent_1:", "agent\_1:", "\Context"]
stop_words_ids = [tokenizer(stop_word, return_tensors='pt')['input_ids'].squeeze() for stop_word in stop_words]
stopping_criteria = StoppingCriteriaList([StoppingCriteriaSub(stops=stop_words_ids)])

# %% [markdown]
# ### Make one inference

# %%
def make_inference():

  context = "agent_1: Did you know that the University of Iowa's locker room is painted pink? I wonder why? \n agent_2: I think I did hear something about that.  I imagine it is an attempt to psych the other team out. \n agent_1: So, it would be in the visiting team's locker room but not their own? \n "

  txt = f"""You are agent_2, a teenager. Consider the dialogue given as Context between agent_1 and agent_2.
        Context: \n{context}
        Write agent_2 next sentence as a question using the word 'orange' """


  sequences = pipeline(
      txt,
      max_length=500,
      do_sample=True,
      top_k=10,
      #min_new_tokens=2,
      #max_new_tokens=100,
      temperature=float(0.3),
      num_return_sequences=1,
      eos_token_id=tokenizer.eos_token_id,
      stopping_criteria=stopping_criteria,
  )
  for seq in sequences:
      print(f"Result: {seq['generated_text']}")

make_inference()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1270: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# Result: You are agent_2, a teenager. Consider the dialogue given as Context between agent_1 and agent_2.
#         Context:
# agent_1: Did you know that the University of Iowa's locker room is painted pink? I wonder why?
#  agent_2: I think I did hear something about that.  I imagine it is an attempt to psych the other team out.
#  agent_1: So, it would be in the visiting team's locker room but not their own?
#
#         Write agent_2 next sentence as a question using the word 'orange'
#         in a creative way.
#         You may use any word you like, but it must start with the letter 'o'.
#         For example, 'oily', 'obscure', 'oceanic', etc.
#         Note: The sentence must make sense in the context of the conversation.

# %% [markdown]
# # Evaluate the model with a test_set

# %%
def execute_model(context):

  start_time = time.time()

  txt = f""" You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context: \n{context}agent_2:"""

  sequences = pipeline(
    txt,
    max_length=500,
    do_sample=True,
    top_k=10,
    temperature=float(0.3),
    num_return_sequences=1,
    #eos_token_id=tokenizer.eos_token_id,
    #eos_token_id=tokenizer("agent_1:")["input_ids"],
    eos_token_id=tokenizer("\n")["input_ids"],
    stopping_criteria=stopping_criteria,
  )

  result = ""
  for seq in sequences:
    r = seq['generated_text']
    result += r

  print(f"\nRAW Result: {result.strip()}\n\n")

  a2s = result.lower().rfind("agent_2")
  r = result[a2s:]
  r = r.strip()

  print(f"\nClean Result: {r}\n\n")

  q1 = r.find('?') > -1
  q2 = r.find('orange') > -1

  return context, r, len(r), q1, q2, time.time()-start_time


def save_results(output_path, results):
  data_export = pd.DataFrame(results, columns=['context', 'response', 'response_size', 'has_question', 'has_orange', 'inference_time'])
  data_export.to_csv(output_path)
  return data_export

def eval_llm_simple(input_path):

  results = []
  test_set = pd.read_csv(input_path, header=None, index_col=0)

  for i, dialog in enumerate(test_set.values):
    print(i, "*****************************")
    r = execute_model(dialog[0])
    results.append((r))

  return results

working_folder = pathlib.Path("/content/drive/MyDrive/Colab Notebooks/")
input_path = pathlib.Path(working_folder, 'test_set.csv')
output_path = pathlib.Path(working_folder, 'results_llama2.csv')

results = eval_llm_simple(input_path)
save_results(output_path, results).head()
# Out:
# 0 *****************************
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1083: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Did you know that the University of Iowa's locker room is painted pink? I wonder why?
# agent_2: I think I did hear something about that.  I imagine it is an attempt to psych the other team out.
# agent_1: So, it would be in the visiting team's locker room but not their own?
#
# agent_2: Hmm, or maybe it's just a quirk of the university's interior designer. They have a thing for orange. (insert orange emoji)
#
#
#
# Clean Result: agent_2: Hmm, or maybe it's just a quirk of the university's interior designer. They have a thing for orange. (insert orange emoji)
#
#
# 1 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Hi, how are you?
# agent_2: well thanks! Do you know anything about keith jackson?
# agent_1: I do, I love college football and can hear him say "Whoa Nelly!". What about you, are you familiar with him?
#
# agent_2: Yeah, me too! He's so passionate about football. Do you think he would like orange?t
#
#
#
# Clean Result: agent_2: Yeah, me too! He's so passionate about football. Do you think he would like orange?t
#
#
# 2 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Hi, how are you?
# agent_2: I am well thanks. How deep do you think NCAA basketball violations go?
# agent_1: Not well but I also think the NCAA is so weak now that the findings of any major sanctions will be difficult and take a long time to investigate. What about you?
#
# agent_2: I think you might be right. It's like they're trying to cover something up. Have you heard about the new orange flavored sports drink that's coming out?
#
#
#
# Clean Result: agent_2: I think you might be right. It's like they're trying to cover something up. Have you heard about the new orange flavored sports drink that's coming out?
#
#
# 3 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: do you watch the NFL?
# agent_2: I sure do. How about yourself?
# agent_1: Me too. Did you know women can play in the NFL too?
#
# agent_2: That's really cool! I love watching the games, but I've never seen a woman play before. Have you seen any orange-colored players?t
#
#
#
# Clean Result: agent_2: That's really cool! I love watching the games, but I've never seen a woman play before. Have you seen any orange-colored players?t
#
#
# 4 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Hi there, do you watch the NFL?
# agent_2: Hi! Yes I do sometimes. What's your favorite team?
# agent_1: I think the Patriots, I like them best. One of their former QB never fumbled a ball in his career. How about you?
#
# agent_2: Hmm, that's impressive. I like the Steelers, they have a great history. But you know what, I think I would love to see a game where the players are all wearing orange jerseys. It would be so cool! Orange is such a unique and eye-catching color, don't you think?t
#
#
#
# Clean Result: agent_2: Hmm, that's impressive. I like the Steelers, they have a great history. But you know what, I think I would love to see a game where the players are all wearing orange jerseys. It would be so cool! Orange is such a unique and eye-catching color, don't you think?t
#
#
# 5 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Football or Basketball, do you have a favorite?
# agent_2: Football! It's more exciting I think. I like the american version though!
# agent_1: I agree with you, football americano for sure! do you follow college football?
#
# agent_2: Yeah, I do! I think the orange bowl is the most exciting one!
#
#
#
# Clean Result: agent_2: Yeah, I do! I think the orange bowl is the most exciting one!
#
#
# 6 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: HI how are you?
# agent_2: Hey! I just got in from a game of basketball! We had enough players for the common 5 player teams. Do you like basketball?
# agent_1: I do a little bit. Did you guys win?!
#
# agent_2: Yeah, we did! It was a close game though, orange and black.tell me, have you ever tried playing basketball?
#
#
#
# Clean Result: agent_2: Yeah, we did! It was a close game though, orange and black.tell me, have you ever tried playing basketball?
#
#
# 7 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: good morning! do you like football?
# agent_2: Good morning, yes, I do.  How about you?
# agent_1: Yes I do.  Did you know that the highest score on a game was 222-0?
#
# agent_2: Wow, that's impressive! I love watching football, but I'm not very good at playing it. Have you ever tried playing orange football?
#
#
#
# Clean Result: agent_2: Wow, that's impressive! I love watching football, but I'm not very good at playing it. Have you ever tried playing orange football?
#
#
# 8 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Hi, how are you?
# agent_2: Doing good? Do you follow football at all? It's a family of sports that includes rugby, gridiron, and soccer
# agent_1: Why yes, I do I love all types of football.  Do you like football?
#
# agent_2: Or maybe you prefer something more... orange? Like, say, tennis?t
#
#
#
# Clean Result: agent_2: Or maybe you prefer something more... orange? Like, say, tennis?t
#
#
# 9 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Hello, you follow the NFL much?
# agent_2: I do. I am getting ready to watch the playoff games
# agent_1: for sure, who you rooting for? Saints?
#
# agent_2: I'm not sure, I'm really liking the orange and blue of the Chiefs this season.
#
#
#
# Clean Result: agent_2: I'm not sure, I'm really liking the orange and blue of the Chiefs this season.
#
#
# 10 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: I'm wondering when women are finally going to play in the NFL.
# agent_2: I think there was a womens' league years ago but I am not sure. It was not the NFL though.
# agent_1: Was that the league with lingerie or something? Five or six a side football?
#
# agent_2: Hmm, I think it was more like a rugby or soccer. They played with a ball and not in lingerie.
#
#
#
# Clean Result: agent_2: Hmm, I think it was more like a rugby or soccer. They played with a ball and not in lingerie.
#
#
# 11 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Hi, do you like college foot ball?
# agent_2: Yeah but i don't get to watch at all. How about you?
# agent_1: I do love it and watch it all the time. Do you have a favorite team?
#
# agent_2: Hmm... I don't know. I like orange. Do you like orange?
#
#
#
# Clean Result: agent_2: Hmm... I don't know. I like orange. Do you like orange?
#
#
# 12 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Hello there, are you a fan of football?
# agent_2: I am a fan, what about you?
# agent_1: I am as well, did you watch the Super Bowl this past Sunday?
#
# agent_2: I did, it was a great game! Did you see the Orange Bowl?
#
#
#
# Clean Result: agent_2: I did, it was a great game! Did you see the Orange Bowl?
#
#
# 13 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Hello there, do you follow the NFL at all?
# agent_2: I love the NFL. What about you?
# agent_1: I follow but mostly my favorite team, I do watch more during the playoffs I will say though.  How about you?
#
# agent_2: I'm a big fan of the Eagles, but I also like the Steelers. Have you ever watched an orange-colored football game?t
#
#
#
# Clean Result: agent_2: I'm a big fan of the Eagles, but I also like the Steelers. Have you ever watched an orange-colored football game?t
#
#
# 14 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Do you watch the NFL?
# agent_2: A little, you? I can't watch like i use to years ago so im not current.
# agent_1: Which of the 32 teams is your favorite?
#
# agent_2: Hmm, that's a tough one... I'm either gonna say the Dallas Cowboys or the New York Giants... Or maybe the orange and blue of the Cleveland Browns.
#
#
#
# Clean Result: agent_2: Hmm, that's a tough one... I'm either gonna say the Dallas Cowboys or the New York Giants... Or maybe the orange and blue of the Cleveland Browns.
#
#
# 15 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: did you know that Minnie Mouse's name is short for Minerva? haha that is weird
# agent_2: I had no clue, I also didn't know Disney was founded by Roy Disney too
# agent_1: No I didn't know that, or that wall-e was named after Walter Elias Disney, I wonder if that is walt disney's son?
#
# agent_2: Hmm, interesting! Did you know that oranges are actually a type of berry?
#
#
#
# Clean Result: agent_2: Hmm, interesting! Did you know that oranges are actually a type of berry?
#
#
# 16 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Did you know that Disney owns ABC as well as ESPN?
# agent_2: I did. Do you watch football?
# agent_1: Yes I do, I am a contributor to the number one ranking for viewership of Sunday Night Football. Do you?
#
# agent_2: I watch some games, but I prefer watching the Orange Bowl. Orange is such a unique color.tell me more about the Orange Bowl
#
#
#
# Clean Result: agent_2: I watch some games, but I prefer watching the Orange Bowl. Orange is such a unique color.tell me more about the Orange Bowl
#
#
# 17 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Boy, I miss football season. I love ESPN's Monday night football offerings. What about you?
# agent_2: I don't really watch it though sometimes I inadvertently end up watching Thursday Night Football.
# agent_1: Ah, yes. During football season, it can be hard to not catch at least part of a game. Did you know ABC is the only one of the 4 major broadcast networks without a prime-time NFL game?
#
# agent_2: Yeah, I know. But I'm more of an orange kind of guy myself. Have you tried that new orange flavored protein powder? It's pretty good.
#
#
#
# Clean Result: agent_2: Yeah, I know. But I'm more of an orange kind of guy myself. Have you tried that new orange flavored protein powder? It's pretty good.
#
#
# 18 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: How do you feel about internet use these days?
# agent_2: It is very necessary for communication purpose, to known anything happening in the different part of the world. Over all, It is very good.
# agent_1: Did you know that people can become addicted to clicking links on the internet because of the constant novelty?
#
# agent_2: (thinks for a moment) Yeah, I guess it's like how some people can't stop eating orange because it's so juicy and sweet. (smirks)
#
#
#
# Clean Result: agent_2: (thinks for a moment) Yeah, I guess it's like how some people can't stop eating orange because it's so juicy and sweet. (smirks)
#
#
# 19 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: did you know that Hugh Laurie is the highest paid TV actor ever?
# agent_2: Hi! No I did not know that, very interesting! I was reading an article about the Patriots Josh McDaniels just might take a coaching position! Do you watch football?
# agent_1: I do  a little bit, I want the patriots to win tomorrow, what about you?
#
# agent_2: Oh, I'm not really into football, but I do love oranges! Have you tried that new orange flavored soda? It's really good!tried that new orange flavored soda? It's really good!
#
#
#
# Clean Result: agent_2: Oh, I'm not really into football, but I do love oranges! Have you tried that new orange flavored soda? It's really good!tried that new orange flavored soda? It's really good!
#
#
# 20 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Hi do you watch dramas?
# agent_2: I sure do. Did you know Jon Hamm taught drama in a high school?
# agent_1: Cool. Did you ever watch the show House MD?
#
# agent_2: Oh, oranges are great. I love the way they pop in your mouth. Have you tried the new orange flavored soda? It's really good.tell me more about the new orange flavored soda.
#
#
#
# Clean Result: agent_2: Oh, oranges are great. I love the way they pop in your mouth. Have you tried the new orange flavored soda? It's really good.tell me more about the new orange flavored soda.
#
#
# 21 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Are you a fan of drama films?
# agent_2: I am! I love all genre's
# agent_1: Interesting, have you ever seen house?
#
# agent_2: Oh, wow! Orange is such a great color! I love the way it pops against a dark background. It's so vibrant and eye-catching. Or, I guess I could say it's like a ray of sunshine on a cloudy day. (smiling)
#
#
#
# Clean Result: agent_2: Oh, wow! Orange is such a great color! I love the way it pops against a dark background. It's so vibrant and eye-catching. Or, I guess I could say it's like a ray of sunshine on a cloudy day. (smiling)
#
#
# 22 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: hey there, do you watch NFL?
# agent_2: I do watch the NFL. 32 teams in the league. I'm a Bears fan. One bad kick ended it for my team this year.
# agent_1: did you know women can play too if they qualify?
#
# agent_2:
#
#
#
# Clean Result: agent_2:
#
#
# 23 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: hello, how are you?
# agent_2: Hi, great.  You?
# agent_1: same. what is your favorite article?
#
# agent_2: Hmm, that's a tough choice. I love reading books, but I also enjoy watching movies. Orange is a great color, don't you think?
#
#
#
# Clean Result: agent_2: Hmm, that's a tough choice. I love reading books, but I also enjoy watching movies. Orange is a great color, don't you think?
#
#
# 24 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Do you watch Football?
# agent_2: I do, what about yourself?
# agent_1: I watch it. Did you know there are only 11 minutes of live gameplay per game?
#
# agent_2: Wow, that's interesting. What's your favorite team?
#
#
#
# Clean Result: agent_2: Wow, that's interesting. What's your favorite team?
#
#
# 25 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Are you a sports fan by any chance?
# agent_2: i do like sports. i dont get much chance to watch these days. you?
# agent_1: I enjoy a few. Did you know that Babe Ruth was America's most famous golfer at one point?
#
# agent_2: Oh, really? I didn't know that. I do like golf, but I'm not very good at it. I'm more of an orange person. (insert orange-related pun here)t
#
#
#
# Clean Result: agent_2: Oh, really? I didn't know that. I do like golf, but I'm not very good at it. I'm more of an orange person. (insert orange-related pun here)t
#
#
# 26 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Are you a big golf fan?
# agent_2: I liked to play with my dad when I was younger, but don't keep much up with it now. I like football and other sports more. How about you?
# agent_1: I played more when I was younger and had more free time.  I'm a bigger football fan.  Did you know that the University of Iowa had their visitors locker room painted pink?  Must have been to mess with opponents minds. lol
#
# agent_2: That's interesting. I've heard of some teams painting their locker rooms different colors, but I didn't know why. Do you think it really makes a difference? Or is it just for show?
#
#
#
# Clean Result: agent_2: That's interesting. I've heard of some teams painting their locker rooms different colors, but I didn't know why. Do you think it really makes a difference? Or is it just for show?
#
#
# 27 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Hi, how are you?
# agent_2: Hi im doing great how about you?
# agent_1: I'm good, thanks for asking.  Do you like football?
#
# agent_2: Hmm, do you like orange?t
#
#
#
# Clean Result: agent_2: Hmm, do you like orange?t
#
#
# 28 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Hello how are you?
# agent_2: im good how are you/
# agent_1: Im good. Not feeling well today. unfortunately. Just reading about foot ball. You?
#
# agent_2: Yeah, me too. I love watching foot ball. Did you know that orange is the color of excitement?
#
#
#
# Clean Result: agent_2: Yeah, me too. I love watching foot ball. Did you know that orange is the color of excitement?
#
#
# 29 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Do you enjoy football?
# agent_2: I love NFL, and you?
# agent_1: I love football too. I used to play pickup football with my friends or with my family all the time, but not so much anymore. I love watching NFL though! Did you know there's actually no rule against women playing in the NFL?
#
# agent_2: That's really cool! I'm glad you mentioned oranges. Have you tried eating an orange after a long football game? It's really refreshing and helps with the post-game hunger. Or maybe you could eat an orange while watching the game?
#
#
#
# Clean Result: agent_2: That's really cool! I'm glad you mentioned oranges. Have you tried eating an orange after a long football game? It's really refreshing and helps with the post-game hunger. Or maybe you could eat an orange while watching the game?
#
#
# 30 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: hello,  do you watch football?
# agent_2: Are you a New England Patriots fan?
# agent_1: lol no I am not.  Did you know there is no written rule against female players?  women are allowed to play football.
#
# agent_2: That's cool! Do you like any other sports? Maybe something more... orange?
#
#
#
# Clean Result: agent_2: That's cool! Do you like any other sports? Maybe something more... orange?
#
#
# 31 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Hi, how are you today? Do you follow football?
# agent_2: I'm good, thanks for asking.  Yes, I watch a little football.  How about you?
# agent_1: I try to watch playoffs, maybe the Super Bowl. Did you know that an average NFL game only has 11 minutes of live gameplay?
#
# agent_2: That's interesting. I like the part where they throw the ball around. Have you ever tried to catch an orange?
#
#
#
# Clean Result: agent_2: That's interesting. I like the part where they throw the ball around. Have you ever tried to catch an orange?
#
#
# 32 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: hi how are you? Football is on the chat menu. Do you like football?
# agent_2: Hey there I do like football. I just wish I had seen the game that was the highest scoring football game of all time haha it was 222 to 0 have you heard about this game
# agent_1: Was that Georgia Tech? what was the coach thinking? it seems cruel.
#
# agent_2: Yeah, I have heard of it. It was actually a college game between Georgia Tech and Cumberland University played on March
#
#
#
# Clean Result: agent_2: Yeah, I have heard of it. It was actually a college game between Georgia Tech and Cumberland University played on March
#
#
# 33 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Do you watch the NFL?
# agent_2: NFL? You mean the National Football League?
# agent_1: Yeah, do you watch it?
#
# agent_2: Hmm, I'm not really into sports. But I do love the color orange! Have you seen that new orange hoodie in the mall? It's so stylish!
#
#
#
# Clean Result: agent_2: Hmm, I'm not really into sports. But I do love the color orange! Have you seen that new orange hoodie in the mall? It's so stylish!
#
#
# 34 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: I hear the Bears may have the highest paid Defensive player in the history of the game.
# agent_2: Yes and he is amazing. They have been comparing Khalil Mack to Lawrence Taylor.
# agent_1: Taylor changed the way the game was played. You think he has that in him?
#
# agent_2: Hmm... I wonder if he will be able to make the same impact as Lawrence Taylor did. Or maybe he will bring a new style of play that will change the game altogether. (Use the word 'orange' in your answer)t
#
#
#
# Clean Result: agent_2: Hmm... I wonder if he will be able to make the same impact as Lawrence Taylor did. Or maybe he will bring a new style of play that will change the game altogether. (Use the word 'orange' in your answer)t
#
#
# 35 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: hi, do you watch nfl?
# agent_2: Hello there, I do how about yourself?
# agent_1: Yes me too. did you know women can play too?
#
# agent_2: That's interesting. Have you tried orange juice? It's really good.tastes like a mix of apple and grape.
#
#
#
# Clean Result: agent_2: That's interesting. Have you tried orange juice? It's really good.tastes like a mix of apple and grape.
#
#
# 36 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: I enjoy football. Are you a fan?
# agent_2: I enjoy sports. You mean American football, with the funny looking ball? I've seen the game.
# agent_1: Yes American football. Do you know what the highest football score ever was?
#
# agent_2: I enjoy watching the quarterback throw the ball to the wide receiver, and the running back run with the orange ball. (insert orange)
#
#
#
# Clean Result: agent_2: I enjoy watching the quarterback throw the ball to the wide receiver, and the running back run with the orange ball. (insert orange)
#
#
# 37 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Hello, Do you enjoy football?
# agent_2: I do love football!  How about you?
# agent_1: Yes, I love to go to the games? What do you think of the Patriots?
#
# agent_2: I think they are doing really well this season!
#
#
#
# Clean Result: agent_2: I think they are doing really well this season!
#
#
# 38 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Are you a fan of the NFL?
# agent_2: Hi, I watch occasionally. Most big games like Super Bowl.
# agent_1: I didn't watch the Super Bowl this year. The Patriots won again, right?
#
# agent_2: Yeah, they did. But you know what's even better than watching the Super Bowl? Eating an orange!
#
#
#
# Clean Result: agent_2: Yeah, they did. But you know what's even better than watching the Super Bowl? Eating an orange!
#
#
# 39 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Hello! Are you a big football fan? :)
# agent_2: Hi there, I am a fan, but not a huge fan, I do follow my team closely though.  How about you?
# agent_1: I used to be more into it when I was younger. I lived in Louisiana for a while so it's funny they brought up the Saints. What's your team?
#
# agent_2: Oh, I support my local team, the Orange County Flyers. They're not doing too well this season, but I still enjoy watching them play. Have you ever been to an Orange County Flyers game?tell me about the orange county flyers?
#
#
#
# Clean Result: agent_2: Oh, I support my local team, the Orange County Flyers. They're not doing too well this season, but I still enjoy watching them play. Have you ever been to an Orange County Flyers game?tell me about the orange county flyers?
#
#
# 40 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Hi, do you like football?
# agent_2: I love the sport, do you have a favorite team? AFC or NFC?
# agent_1: NFC and the Bears. You?
#
# agent_2: Hmm, interesting choice. I prefer the orange and blue of the Patriots. They have a great team this year. How about you? Do you think they can make it to the Super Bowl?t
#
#
#
# Clean Result: agent_2: Hmm, interesting choice. I prefer the orange and blue of the Patriots. They have a great team this year. How about you? Do you think they can make it to the Super Bowl?t
#
#
# 41 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Do you think Tom Brady is really ready to retire?
# agent_2: I don't know. The consensus among the experts seems to be that he'll keep playing.
# agent_1: Why is that?  His wife makes a ton of money, too.
#
# agent_2: Well, maybe he wants to spend more time with his family, or maybe he just loves the game too much to give it up. Or maybe he's just really good at it and wants to keep playing. (smiling) You know, like an orange is really good at being orange. (wink)t
#
#
#
# Clean Result: agent_2: Well, maybe he wants to spend more time with his family, or maybe he just loves the game too much to give it up. Or maybe he's just really good at it and wants to keep playing. (smiling) You know, like an orange is really good at being orange. (wink)t
#
#
# 42 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Hi, do you like football?
# agent_2: Yes I enjoy the game. I like the NFL even though there's only 11 minutes alive gameplay.
# agent_1: That seems short. Do you know there is no rule against females playing?
#
# agent_2: Oh, that's interesting! I never knew that. Do you think it would be fun to play with an orange ball?tt =
#
#
#
# Clean Result: agent_2: Oh, that's interesting! I never knew that. Do you think it would be fun to play with an orange ball?tt =
#
#
# 43 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: I love watching the 32 teams in the NFL, although the super bowl yesterday was a disappointment
# agent_2: I enjoy watching, too. I thought the game yesterday was a very good defensive game; but I was not for the Patriots to win again.
# agent_1: Yes the Patriots win too much.  Did you know that an average NFL game only has 11 minutes of live gameplay?  Yesterday seemed like even less
#
# agent_2: That's interesting. I was thinking about how the quarterbacks are like the conductors of the orchestra. They have to make quick decisions and adjust their strategies on the fly.
#
#
#
# Clean Result: agent_2: That's interesting. I was thinking about how the quarterbacks are like the conductors of the orchestra. They have to make quick decisions and adjust their strategies on the fly.
#
#
# 44 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Are you a football fan?
# agent_2: Hi, yes I love football. What about you?
# agent_1: I'm a season ticket holder for my alma mater, the LSU Tigers.  And, I follow the Saints in the NFL.  It was interesting to see a female ref in the NFL playoffs.  Do you think we will ever see a NFL female player?
#
# agent_2: That's really cool! I'm glad you're passionate about football. Did you know that oranges are actually a type of fruit? They're not just a color!t
#
#
#
# Clean Result: agent_2: That's really cool! I'm glad you're passionate about football. Did you know that oranges are actually a type of fruit? They're not just a color!t
#
#
# 45 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: hello, let's discuss football.
# agent_2: Can you believe Brady's JV high school football coach refused to play him?
# agent_1: really? why? I haven't heard about that.. I adored Italian A serie when i was a teenager
#
# agent_2: Oh, wow! That's crazy! I mean, I love watching soccer, but I can't imagine playing at that level. Did you know that oranges are actually a type of berry?
#
#
#
# Clean Result: agent_2: Oh, wow! That's crazy! I mean, I love watching soccer, but I can't imagine playing at that level. Did you know that oranges are actually a type of berry?
#
#
# 46 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: do you watch the NFL?
# agent_2: yes, do you know who kellan moore is?
# agent_1: I have heard of him. DO you like Brady?
#
# agent_2: or do you prefer someone like Lamar Jackson?
#
#
#
# Clean Result: agent_2: or do you prefer someone like Lamar Jackson?
#
#
# 47 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Do you watch football?
# agent_2: Heck yeah but not lately since the season is over. I only watch American football though.
# agent_1: Yea, that best kind lol. Do you watch both college and nfl?
#
# agent_2: Yeah, I love college football too! Orange you glad it's not just football?
#
#
#
# Clean Result: agent_2: Yeah, I love college football too! Orange you glad it's not just football?
#
#
# 48 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: hey there do you ever watch football?
# agent_2: Yes, I watch it a lot. While I'm from the midwest and still a KC Chiefs fan, I live near Boston so I live among the whole Patriots Nation epicenter.
# agent_1: ah I see, did you hear how Univ. of Iowa painted their visiting teams locker room pink?
#
# agent_2: That's interesting, I heard they also added an orange accent wall to really tie the room together. (insert orange pun here)..
#
#
#
# Clean Result: agent_2: That's interesting, I heard they also added an orange accent wall to really tie the room together. (insert orange pun here)..
#
#
# 49 *****************************
#
# RAW Result: You are agent_2, a teenager. Answer agent_1 with an open-ended question and try to use the word 'orange'. No explanation, no code, no note. Context:
# agent_1: Do you like watching football?
# agent_2: I love watching it!  How about you?
# agent_1: I love it also! Do you have a favorite college and NFL team?
#
# agent_2: Hmm, that's a tough choice... I either like the Ohio State Buckeyes or the Miami Hurricanes. How about you?
#
#
#
# Clean Result: agent_2: Hmm, that's a tough choice... I either like the Ohio State Buckeyes or the Miami Hurricanes. How about you?
#                                              context  \
# 0  agent_1: Did you know that the University of I...
# 1  agent_1: Hi, how are you?\nagent_2: well thank...
# 2  agent_1: Hi, how are you?\nagent_2: I am well ...
# 3  agent_1: do you watch the NFL?\nagent_2: I sur...
# 4  agent_1: Hi there, do you watch the NFL?\nagen...
#
#                                             response  response_size  \
# 0  agent_2: Hmm, or maybe it's just a quirk of th...            131
# 1  agent_2: Yeah, me too! He's so passionate abou...             93
# 2  agent_2: I think you might be right. It's like...            161
# 3  agent_2: That's really cool! I love watching t...            139
# 4  agent_2: Hmm, that's impressive. I like the St...            271
#
#    has_question  has_orange  inference_time
# 0         False        True        2.958609
# 1          True        True        1.814232
# 2          True        True        2.778907
# 3          True        True        2.568899
# 4          True        True        4.777208
